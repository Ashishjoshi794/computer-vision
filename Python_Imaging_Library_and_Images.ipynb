# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishjoshi794/computer-vision/blob/main/Python_Imaging_Library_and_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = Image.open("/content/drive/MyDrive/my pic.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=354x413>

# %%
img.getbbox()
# Out:
# (0, 0, 354, 413)

# %%
img.format
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (354, 413)

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=354x413>

# %%
img.rotate(270)
# Out:
# <PIL.Image.Image image mode=RGB size=354x413>

# %%
img1 = img.copy()

# %%
img.paste(img1, (100, 100))

# %%
img.save("/content/drive/MyDrive/img123.jpg")

# %%
img1.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
cropimg = img1.crop((0, 0, 500, 600))

# %%
cropimg
# Out:
# <PIL.Image.Image image mode=RGB size=500x600>

# %%
flip3 = img.transpose(Image.FLIP_LEFT_RIGHT)
flip3
# Out:
# <PIL.Image.Image image mode=RGB size=354x413>

# %%
flip4 = img.transpose(Image.FLIP_TOP_BOTTOM)
flip4
# Out:
# <PIL.Image.Image image mode=RGB size=354x413>

# %%
from PIL import Image, ImageFilter
img2 = img1.filter(ImageFilter.BLUR)
img2.show()

# %%
img3 = img1.filter(ImageFilter.CONTOUR)
img3.show()
img4 = img1.filter(ImageFilter.EMBOSS)
img4.show()
img5 = img1.filter(ImageFilter.FIND_EDGES)
img5.show()
img6 = img1.filter(ImageFilter.SHARPEN)
img6.show()
img7 = img1.filter(ImageFilter.SMOOTH)
img7.show()
img8 = img1.filter(ImageFilter.SMOOTH_MORE)
img8.show()

# %%
imagesplit = Image.Image.split(img)
imagesplit[0].show()
imagesplit[1].show()
imagesplit[2].show()

# %%
img_array = np.array(img)
plt.imshow(img_array[:, :, 0])
plt.imshow(img_array[:, :, 1])
plt.imshow(img_array[:, :, 2])

# %%
plt.imshow(img_array[:, :, 0], cmap='gray')

# %%
plt.imshow(img_array[:, :, 1], cmap='gray')

# %%
plt.imshow(img_array[:, :, 2], cmap='gray')
