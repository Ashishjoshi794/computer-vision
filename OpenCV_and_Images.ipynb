# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishjoshi794/computer-vision/blob/main/OpenCV_and_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread("/content/drive/MyDrive/my pic.jpeg")

# %%
img.shape
# Out:
# (413, 354, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img1 = cv2.imread("adb/fff/cv.jpg")

# %%
plt.imshow(img)

# %%
pic = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %%
pic.shape
# Out:
# (413, 354, 3)

# %%
pic_resize = cv2.resize(pic, (500,1000))
plt.imshow(pic_resize)

# %%
new_pic = cv2.resize(pic,(0,0), pic,0.5,0.5)
plt.imshow(new_pic)

# %%
new_pic.shape
# Out:
# (206, 177, 3)

# %%
new_pic1 = cv2.resize(pic,(0,0), pic,0.5,0.5)
plt.imshow(new_pic1)

# %%
new_pic1.shape
# Out:
# (206, 177, 3)

# %%
pic_flip = cv2.flip(new_pic1, 0)
plt.imshow(pic_flip)

# %%
pic_flip = cv2.flip(new_pic1, -1)
plt.imshow(pic_flip)

# %%
cv2.imwrite('saved.png', new_pic)
# Out:
# True

# %%
new = cv2.imread("/content/saved.png")
plt.imshow(new)
